# %%
# importing all libraries

import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.applications import imagenet_utils
from sklearn.metrics import confusion_matrix
import itertools
import os
import shutil
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# downloading miobilenet
mobile = tf.keras.applications.mobilenet.MobileNet()

# %%
# loading a single image

from IPython.display import Image
Image(filename='C:/Users/Family/Documents/tasks/Image tagging ocr/image_tagging/data/1.PNG', width=300,height=200)

# %%
# checking with single image
preprocessed_image = prepare_image('1.PNG')
predictions = mobile.predict(preprocessed_image)

# %%
results = imagenet_utils.decode_predictions(predictions)

# %%
results
# Out:
# [[('n03782006', 'monitor', 0.38222015),
#   ('n03857828', 'oscilloscope', 0.29231894),
#   ('n04149813', 'scoreboard', 0.13806733),
#   ('n04404412', 'television', 0.066931136),
#   ('n04152593', 'screen', 0.04917246)]]

# %%
# importing more libraries
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input, decode_predictions

# %%
# reading all the images through a function and passing through mobilenet
img_size = 224
for file in os.listdir("data"):
    print(file)
    full_path ="C:/Users/Family/Documents/tasks/Image tagging ocr/image_tagging/data/" + file
    
    image = load_img(full_path,target_size = (img_size,img_size))
    image = img_to_array(image)
    image = np.expand_dims(image, axis=0)
    image = preprocess_input(image)
    predictions = mobile.predict(image)
    results = imagenet_utils.decode_predictions(predictions, top = 3)
    print(results)
    print()
# Out:
# 1.png
# [[('n04152593', 'screen', 0.3474917), ('n03291819', 'envelope', 0.31000277), ('n03782006', 'monitor', 0.07609808)]]
#
# 10.png
# [[('n03782006', 'monitor', 0.45918342), ('n06359193', 'web_site', 0.18454644), ('n07565083', 'menu', 0.11438823)]]
#
# 11.png
# [[('n03598930', 'jigsaw_puzzle', 0.19797137), ('n04209239', 'shower_curtain', 0.18898885), ('n06359193', 'web_site', 0.17459053)]]
#
# 12.png
# [[('n03598930', 'jigsaw_puzzle', 0.6600254), ('n06359193', 'web_site', 0.1824913), ('n04476259', 'tray', 0.090637386)]]
#
# 13.png
# [[('n03782006', 'monitor', 0.7274155), ('n04152593', 'screen', 0.09853788), ('n07565083', 'menu', 0.07717689)]]
#
# 14.png
# [[('n07565083', 'menu', 0.37395927), ('n03782006', 'monitor', 0.22385694), ('n06359193', 'web_site', 0.15806022)]]
#
# 15.png
# [[('n03782006', 'monitor', 0.42609546), ('n04152593', 'screen', 0.25695875), ('n03857828', 'oscilloscope', 0.14421436)]]
#
# 16.png
# ...
