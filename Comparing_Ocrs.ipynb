# %% [markdown]
# # Different OCRs Comparision

# %% [markdown]
# ### For a FULL image

# %% [markdown]
# ### EasyOCR

# %%
#importing required Libraries

import easyocr
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %%
#Reading an image

img = cv2.imread('C:/Users/Family/Documents/tasks/OCR/data/37.png')
plt.imshow(img)

# %%
print(img.shape) # height,width and RGB values
# Out:
# (800, 1280, 3)

# %%
# Applying EasyOCR For an image

reader = easyocr.Reader(['en'])
result = reader.readtext(img,detail=0, paragraph=True)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['Log in VI ware ESx1',
#  'Whats400',
#  'Inbox (1301 #sman dnotiwon',
#  'Weat Wm-Vu-nom',
#  'nomcap pitnor',
#  'Dooqle Sga',
#  'meel  9oo0 com wjt-ivu-gnm?pli= 1&authuser=|',
#  'YYourU presenting',
#  'Gvotyont',
#  'Stop presenting',
#  '1e9] |R W (TR',
#  'Sittlttn',
#  'mkavya sri',
#  'S',
#  'S',
#  '74.21 PM AlientutAnm',
#  "To avoid an infinity mirror don't share your entire screen Or browser windov Share just tabor different window instead:",
#  "'Stop presenting",
#  'Ignore',
#  '421 PM wjt-iwvu-gbm',
#  '2 P',
#  'Tools Benchamuxisx',
#  'Shoa']

# %% [markdown]
# ### Normcap

# %% [markdown]
# meet. google.com
#
# You're presenting to everyone ELSE LR
#
# lo avosd an infinity mirror, don't share your entire screen or browser window, Share Just a tab or a different window instead
#
# 4.21PM wit-iwvu-gbm

# %% [markdown]
# ### Nanonets

# %% [markdown]
# Log in
# -
# VMware ESXI xO WhatsApp x M Inbox (130)
# -
# vsmahidhar@gm x A Meet
# - wjt-iwvu-gbm G normcap python - Google Sear x
# i meet.google.com/wjt-iwvu-gbm?pli31&authuser=1
# + You're presenting to everyone Stop presenting
# *met.google com a d MANO
# m.kavya sri
# S
# Te artend an tymin tiNeen s nd.Shee
# 1atsteor
# 421 PM tw
# To avoid
# an infinity mirror, don't share
# your entire
# screen
# or browser window. Share
# Stop presenting Ignore
# just a tab
# or
# a different window instead.
# You
# 4:21 PM | wjt-iwvu-gbm
# A Tools Benchamr.xlsx Show al

# %% [markdown]
# ### Tesseract OCR

# %%
#importing tessearct
import pytesseract
from PIL import Image

# %%
pytesseract.pytesseract.tesseract_cmd = "C:/Users/Family/AppData/Local/Tesseract-OCR/tesseract.exe"
tessdata_dir_config = '--tessdata-dir "C:/Users/Family/AppData/Local/Tesseract-OCR/tessdata"'

# %%
# image path for single image
img = "C:/Users/Family/Documents/tasks/OCR/data/37.png"

# %%
# Extracting text from image for a single Image
text = pytesseract.image_to_string(img, config=tessdata_dir_config)
print(text)
# Out:
# {& meet google.com
#
#
#
# eer
#
#
#
# To.avoid an infinity mirror, don't share your entire screen or browser window. Share,
# Peet nee!
#
#
#
# ro
# & oa
#
# Pe aes

# %% [markdown]
# ## For a Cropped IMAGE

# %%
# Cropping an image for a Particular Portion to extract the text in a better way

img_crop = img[0:30,0:900]
plt.imshow(img_crop)

# %% [markdown]
# ### EasyOCR

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(img_crop,detail=0, paragraph=True)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# ['Log in VI ware ESx1',
#  'Whats400',
#  'Inbox (1301 #sman dnotiwom',
#  'Neal Wm-Vu-nom',
#  'nomcap pitnor Gooala Sea']

# %% [markdown]
# ### Normcap

# %% [markdown]
# Login - VMware E50 x | @ WhatsApp X | M4 inbox (130) - vemahidhar 8g: X Or Meet - wit-iwvu-gbm ® x G normcep python - Google See X |

# %% [markdown]
# ### Nanonets

# %% [markdown]
# Log in
# -
# VMware ESXI xO WhatsApp x M Inbox (130)
# -
# vsmahidhar@gm x A Meet
# - wjt-iwvu-gbm G normcap python - Google Sear x

# %% [markdown]
# ### Tesseract OCR

# %%
# Extracting text from image for a single Image
text = pytesseract.image_to_string(img_crop, config=tessdata_dir_config)
print(text)
# Out:
#
#
# Login viware £8x1 © Whatsaoo 2X | M4 Inbox (120)-vamahichar@om> x CH Mest-witwwugdm — @ XG normeanpyton Googe Sea x | +
